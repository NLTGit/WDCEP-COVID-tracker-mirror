# %% [markdown]
# [![Binder](https://mybinder.org/badge_logo.svg)](https://notebooks.gesis.org/binder/jupyter/user/nltgit-wdcep-co--tracker-mirror-ug4igogo/notebooks/tracker/notebooks/tracker_v2.ipynb)
#
# # WDCEP Covid-19 impact tracker
#
# High-level trends and data on the impact of Covid-19 and related containment policies on businesses in the District of Columbia.
#
# ## Year on year restaurant trends
#
# ### OpenTable data showing % of seated diners for a given day relative to the same day last year
# Open table samples ~20,000 restaurants on their platform across major cities around the world for this analysis, which is updated daily.
#
# Data source: https://www.opentable.com/state-of-industry

# %%
# !jupyter nbextension enable --py --sys-prefix widg|etsnbextension

# %%
from tracker.plots2 import *

# %% [markdown]
# ### Comparing trends in District of Columbia with Global and USA city averages in Open Table dataset
#
# Shows a 7-day moving average

# %%
ot_dc_usa_all()

# %% [markdown]
# ### Comparing Open Table YoY trends
#
# Select any number of locations below to compare seated diner YoY % trends. Multiple selections possible.

# %%
display(city_widget, outcity)
# Out:
# SelectMultiple(description='Location(s)', options=('United States', 'District of Columbia', 'Atlanta', 'Austin…
# Output()

# %% [markdown]
# ## Cluster analysis of seated diner trends
#
# A K-means cluster analysis of the YoY change in seated diners groups the cities that have the most similar time series together. No other factors (city size, demographics, policies, etc) are considered, this is merely an empirical pattern analysis of the YoY time series meant for exploratory analysis.

# %%
plot_clusters()

# %% [markdown]
# Cluster analysis breaks all the cities in the dataset into clusters. Plotted above are the cluster means (for YoY throughout the year). Below you can select any individual cluster to see the YoY trends of the cities within and compare it to DC and the all-data average.

# %%
display(cluster_widget, outclust)
# Out:
# Dropdown(description='Cluster', options=(1, 2, 3, 4, 5, 6, 7, 8), value=1)
# Output()
